# %% [markdown]
# # 时间向前预测
#
# 本测试严格遵循根目录 `00_PLAN.md`，主要结果使用训练参数固定后的response-before held-out likelihood。

# %%
from pathlib import Path
import sys,json,pandas as pd
WORKSPACE=Path.cwd();RUNTIME=WORKSPACE/'tmp'/'jupyter-notebook'/'runtime';CORE=WORKSPACE/'Markov_test'/'model_artifacts'
for p in (RUNTIME,CORE):
    if str(p) not in sys.path:sys.path.insert(0,str(p))

# %%
from markov_test_core import run_test07
result=run_test07()
result
# Out:
#                    model_name      n            ll  converged  ll_per_trial
# 0           block_plus_markov  50896 -40083.920614         25     -0.787565
# 1  exchangeable_block_mixture  50896 -40825.381931         38     -0.802133
# 2                         hmm  50896 -41800.562643         40     -0.821294
# 3       prior_conditioned_iid  50896 -42631.107432         33     -0.837612

# %%
validation=json.loads((WORKSPACE/'Markov_test'/'07_chronological_prediction'/'validation.json').read_text())
display(pd.Series(validation,name='passed').to_frame())
assert all(validation.values())
# Out:
#              passed
# 192_results    True
# no_overlap     True
# finite         True

# %% [markdown]
# ## 解释边界
#
# 本步骤结论见同目录 `conclusion.md`；最终解释由全部八项测试共同决定。
